# %% [markdown]
# <a href="https://colab.research.google.com/github/gate13162-rgb/Projects/blob/main/Sales_Distribution_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [12000, 15000, 13500, 17000, 16000, 19000,
         18500, 21000, 20000, 22500, 24000, 26000]

subjects = ['Math', 'Science', 'English', 'History', 'Art']
scores   = [78, 85, 72, 90, 65]

study_hours = np.random.uniform(1, 10, 100)
exam_scores = study_hours * 8 + np.random.normal(0, 5, 100)

product_sales = np.random.normal(loc=50, scale=10, size=200)

#Task 1 — Line Plot: Monthly Sales Trend

import matplotlib.pyplot as plt
plt.plot(months, sales,color='orange', marker='o', linestyle='--', linewidth=2)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.show()

# Task 2 — Bar Plot: Subject Score Comparison

plt.bar (subjects,scores,color='green')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.title('Subject Scores Comparision')
plt.show()

#Task 3 — Scatter Plot: Study Hours vs Exam Score
sns.scatterplot(x=study_hours, y=exam_scores,color='skyblue')
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.title('Study Hours vs Exam Scores')
plt.show()

# Task 4 — Box Plot: Product Sales Distribution
plt.boxplot(product_sales)
plt.xlabel('Product Sales')
plt.title('Product Sales')
plt.show()
